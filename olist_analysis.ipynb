# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import plotly.express as px

# %%
df = pd.read_csv('/Users/anuka/Desktop/brazillian_data-findings/03_revenue_by_state/product_by_state_pct_category.csv')
df.head(5)
# Out:
#   product_category_name_english customer_state customer_state_full  \
# 0    agro_industry_and_commerce             MG        Minas Gerais
# 1    agro_industry_and_commerce             SP           São Paulo
# 2    agro_industry_and_commerce             RJ      Rio de Janeiro
# 3              air_conditioning             SP           São Paulo
# 4              air_conditioning             RJ      Rio de Janeiro
#
#    total_payment  rank  pct_of_category
# 0       44016.72     1            38.07
# 1       30871.12     2            26.70
# 2        9770.67     3             8.45
# 3       42274.58     1            47.58
# 4       23252.50     2            26.17

# %% [markdown]
# I want to analyze and visualize which categories generate the most revenue accross Top 3 states in Brazil

# %%
# Looking at the total_payment and summing up by category
# After that getting the largest 10 categories by sum of total payment
top_categories = df.groupby('product_category_name_english')['total_payment'].sum().nlargest(10).index
top_categories
# Out:
# Index(['bed_bath_table', 'computers_accessories', 'health_beauty',
#        'furniture_decor', 'watches_gifts', 'sports_leisure', 'housewares',
#        'garden_tools', 'auto', 'cool_stuff'],
#       dtype='object', name='product_category_name_english')

# %%
# Filter the dataframe to only include top 10 categories
# Create a filtered dataframe containing only rows from the top 10 categories
df_top = df[df['product_category_name_english'].isin(top_categories)]
df_top
# Out:
#     product_category_name_english customer_state customer_state_full  \
# 15                           auto             SP           São Paulo
# 16                           auto             MG        Minas Gerais
# 17                           auto             RJ      Rio de Janeiro
# 21                 bed_bath_table             SP           São Paulo
# 22                 bed_bath_table             RJ      Rio de Janeiro
# 23                 bed_bath_table             MG        Minas Gerais
# 45          computers_accessories             SP           São Paulo
# 46          computers_accessories             RJ      Rio de Janeiro
# 47          computers_accessories             MG        Minas Gerais
# 60                     cool_stuff             SP           São Paulo
# 61                     cool_stuff             RJ      Rio de Janeiro
# 62                     cool_stuff             MG        Minas Gerais
# 117               furniture_decor             SP           São Paulo
# 118               furniture_decor             RJ      Rio de Janeiro
# 119               furniture_decor             MG        Minas Gerais
# 126                  garden_tools             SP           São Paulo
# 127                  garden_tools             RJ      Rio de Janeiro
# 128                  garden_tools             MG        Minas Gerais
# 129                 health_beauty             SP           São Paulo
# 130                 health_beauty             MG        Minas Gerais
# 131                 health_beauty             RJ      Rio de Janeiro
# 147                    housewares             SP           São Paulo
# 148                    housewares             MG        Minas Gerais
# 149                    housewares             RJ      Rio de Janeiro
# 194                sports_leisure             SP           São Paulo
# 195                sports_leisure             RJ      Rio de Janeiro
# 196                sports_leisure             MG        Minas Gerais
# 209                 watches_gifts             SP           São Paulo
# 210                 watches_gifts             RJ      Rio de Janeiro
# 211                 watches_gifts             MG        Minas Gerais
#
#      total_payment  rank  pct_of_category
# 15       268468.08     1            32.20
# 16        99769.84     2            11.97
# 17        82395.77     3             9.88
# 21       756727.97     1            44.71
# 22       242431.81     2            14.32
# 23       216969.38     3            12.82
# 45       622332.38     1            40.17
# 46       189763.18     2            12.25
# 47       170939.37     3            11.03
# 60       245073.71     1            32.91
# 61        97561.95     2            13.10
# 62        86486.54     3            11.61
# 117      533872.18     1            38.29
# 118      177682.75     2            12.74
# 119      154998.20     3            11.12
# 126      254857.78     1            31.44
# 127      113245.71     2            13.97
# 128      102524.02     3            12.65
# 129      604558.90     1            37.30
# 130      196285.96     2            12.11
# 131      178266.90     3            11.00
# 147      434929.47     1            40.66
# 148      135835.48     2            12.70
# 149      129491.59     3            12.10
# 194      509044.62     1            37.72
# 195      174834.05     2            12.96
# 196      153371.65     3            11.37
# 209      492762.84     1            35.52
# 210      207651.19     2            14.97
# 211      137957.88     3             9.94

# %%
# Create pivot table with states as rows and categories as columns and total_payment as values
pivot_df = df_top.pivot(index='customer_state_full', columns = 'product_category_name_english', values = 'total_payment')
pivot_df
# Out:
# product_category_name_english       auto  bed_bath_table  \
# customer_state_full
# Minas Gerais                    99769.84       216969.38
# Rio de Janeiro                  82395.77       242431.81
# São Paulo                      268468.08       756727.97
#
# product_category_name_english  computers_accessories  cool_stuff  \
# customer_state_full
# Minas Gerais                               170939.37    86486.54
# Rio de Janeiro                             189763.18    97561.95
# São Paulo                                  622332.38   245073.71
#
# product_category_name_english  furniture_decor  garden_tools  health_beauty  \
# customer_state_full
# Minas Gerais                         154998.20     102524.02      196285.96
# Rio de Janeiro                       177682.75     113245.71      178266.90
# São Paulo                            533872.18     254857.78      604558.90
#
# product_category_name_english  housewares  sports_leisure  watches_gifts
# customer_state_full
# Minas Gerais                    135835.48       153371.65      137957.88
# Rio de Janeiro                  129491.59       174834.05      207651.19
# São Paulo                       434929.47       509044.62      492762.84

# %%
# Create a grouped bar chart showing revenue by state and category
pivot_df.plot(kind='bar', figsize=(14,7), colormap='tab20b')
plt.title ('Revenue by State - Top 10 Product Categories', fontsize = 16)
plt.xlabel('State', fontsize = 14)
plt.ylabel('Total Revenue', fontsize = 14)
plt.xticks(rotation=0,fontsize=12)
plt.yticks(fontsize =12)

# Format the y-axis with commas
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x): ,}'))
plt.legend(title='Category', bbox_to_anchor = (1.05, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Here I will visualize Top 5 states by revenue after getting data from SQL analysis

# %%
df2 = pd.read_csv('/Users/anuka/Documents/python_projects/october/data/Top5_states_by_revenue.csv')
df2
# Out:
#   customer_state         state_name  total_revenue
# 0             SP          Sao Paulo     5770266.19
# 1             RJ     Rio de Janeiro     2055690.45
# 2             MG       Minas Gerais     1819277.61
# 3             RS  Rio Grande do Sul      861802.40
# 4             PR             Parana      781919.55

# %%
df2.plot(kind='bar', x='state_name', y='total_revenue', figsize=(12,6), legend=False, color='steelblue')
plt.title('Top 5 states that generate most revenue', fontsize=18)
plt.xlabel('State', fontsize=14)
plt.ylabel('Total Revenue', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize = 12)
plt.yticks(fontsize=12)

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x):,}'))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Next I want to visualize Top 3 categories per state visualization:

# %%
df3 = pd.read_csv('//Users/anuka/Documents/python_projects/october/data/products_by_region.csv')
df3.head(5)
# Out:
#   customer_state customer_state_full product_category_name_english  \
# 0             AC                Acre               furniture_decor
# 1             AC                Acre                sports_leisure
# 2             AC                Acre                 health_beauty
# 3             AL             Alagoas                 health_beauty
# 4             AL             Alagoas         computers_accessories
#
#    total_payment  rank
# 0        5261.23     1
# 1        2071.54     2
# 2        2067.62     3
# 3       14741.33     1
# 4       14280.47     2

# %%
# There are total of 27 states, since visuazliation is difficult to see each states, i divide into each regions
states = df3['customer_state_full'].unique()
n_states = len(states)
n_states
# Out:
# 27

# %%
# Make the categories as index and columns as state names
pivot2_df = df3.pivot(index='product_category_name_english', columns = 'customer_state_full', values='total_payment')
pivot2_df
# Out:
# customer_state_full               Acre   Alagoas    Amapá  Amazonas     Bahia  \
# product_category_name_english
# auto                               NaN       NaN      NaN       NaN       NaN
# bed_bath_table                     NaN       NaN  1899.93       NaN       NaN
# computers_accessories              NaN  14280.47  4128.95   5866.85  58308.56
# fixed_telephony                    NaN       NaN      NaN       NaN       NaN
# furniture_decor                5261.23       NaN      NaN       NaN       NaN
# garden_tools                       NaN       NaN      NaN   2267.80       NaN
# health_beauty                  2067.62  14741.33      NaN   4566.70  65382.14
# housewares                         NaN       NaN      NaN       NaN       NaN
# signaling_and_security             NaN       NaN      NaN       NaN       NaN
# sports_leisure                 2071.54       NaN      NaN       NaN  57880.04
# telephony                          NaN       NaN      NaN       NaN       NaN
# watches_gifts                      NaN  13249.34  2016.42       NaN       NaN
#
# customer_state_full               Ceará  Espírito Santo  Federal District  \
# product_category_name_english
# auto                                NaN             NaN               NaN
# bed_bath_table                      NaN        34481.72               NaN
# computers_accessories          19148.15             NaN          38634.68
# fixed_telephony                     NaN        30248.54               NaN
# furniture_decor                     NaN             NaN               NaN
# garden_tools                        NaN             NaN               NaN
# health_beauty                  45615.12             NaN          38294.58
# housewares                          NaN             NaN               NaN
# signaling_and_security              NaN             NaN               NaN
# sports_leisure                      NaN             NaN          36794.64
# telephony                           NaN             NaN               NaN
# watches_gifts                  35362.19        32627.85               NaN
#
# customer_state_full               Goiás  Maranhão  ...     Piauí  \
# product_category_name_english                      ...
# auto                           57732.00       NaN  ...  20026.82
# bed_bath_table                      NaN       NaN  ...  10397.57
# computers_accessories               NaN  32283.55  ...       NaN
# fixed_telephony                     NaN       NaN  ...       NaN
# furniture_decor                     NaN       NaN  ...       NaN
# garden_tools                   42451.17       NaN  ...       NaN
# health_beauty                       NaN  17625.19  ...  14944.45
# housewares                     41963.90       NaN  ...       NaN
# signaling_and_security              NaN       NaN  ...       NaN
# sports_leisure                      NaN  14281.47  ...       NaN
# telephony                           NaN       NaN  ...       NaN
# watches_gifts                       NaN       NaN  ...       NaN
#
# customer_state_full            Rio Grande do Norte  Rio Grande do Sul  \
# product_category_name_english
# auto                                           NaN                NaN
# bed_bath_table                                 NaN           93423.36
# computers_accessories                          NaN          108472.88
# fixed_telephony                                NaN                NaN
# furniture_decor                                NaN           93386.58
# garden_tools                                   NaN                NaN
# health_beauty                             16112.05                NaN
# housewares                                     NaN                NaN
# signaling_and_security                         NaN                NaN
# sports_leisure                                 NaN                NaN
# telephony                                  6783.72                NaN
# watches_gifts                             12269.07                NaN
#
# customer_state_full            Rio de Janeiro  Rondônia  Roraima  \
# product_category_name_english
# auto                                      NaN       NaN      NaN
# bed_bath_table                      242431.81       NaN  1532.36
# computers_accessories               189763.18       NaN      NaN
# fixed_telephony                           NaN       NaN      NaN
# furniture_decor                           NaN       NaN  1172.05
# garden_tools                              NaN       NaN      NaN
# health_beauty                             NaN   8517.22      NaN
# housewares                                NaN       NaN      NaN
# signaling_and_security                    NaN       NaN      NaN
# sports_leisure                            NaN   5202.34  2579.08
# telephony                                 NaN       NaN      NaN
# watches_gifts                       207651.19   5010.18      NaN
#
# customer_state_full            Santa Catarina  Sergipe  São Paulo  Tocantins
# product_category_name_english
# auto                                      NaN      NaN        NaN        NaN
# bed_bath_table                            NaN      NaN  756727.97        NaN
# computers_accessories                63469.16      NaN  622332.38        NaN
# fixed_telephony                           NaN      NaN        NaN        NaN
# furniture_decor                      60206.09  8544.12        NaN        NaN
# garden_tools                              NaN  7908.35        NaN        NaN
# health_beauty                             NaN  9639.74  604558.90    8368.96
# housewares                                NaN      NaN        NaN        NaN
# signaling_and_security                    NaN      NaN        NaN        NaN
# sports_leisure                       60391.48      NaN        NaN    6961.25
# telephony                                 NaN      NaN        NaN        NaN
# watches_gifts                             NaN      NaN        NaN    6719.31
#
# [12 rows x 27 columns]

# %%
# create regional mapping: 
region_map = {
    'Acre': 'North', 'Amazonas': 'North', 'Amapá': 'North', 'Pará': 'North', 
    'Rondônia': 'North', 'Roraima': 'North', 'Tocantins': 'North',
    'Alagoas': 'Northeast', 'Bahia': 'Northeast', 'Ceará': 'Northeast', 
    'Maranhão': 'Northeast', 'Paraíba': 'Northeast', 'Pernambuco': 'Northeast', 
    'Piauí': 'Northeast', 'Rio Grande do Norte': 'Northeast', 'Sergipe': 'Northeast',
    'Federal District': 'Central-West', 'Goiás': 'Central-West', 
    'Mato Grosso': 'Central-West', 'Mato Grosso do Sul': 'Central-West',
    'Espírito Santo': 'Southeast', 'Minas Gerais': 'Southeast', 
    'Rio de Janeiro': 'Southeast', 'São Paulo': 'Southeast',
    'Paraná': 'South', 'Rio Grande do Sul': 'South', 'Santa Catarina': 'South'
}

# %%
# Map each region and create new column 
df3['region'] = df3['customer_state_full'].map(region_map)
df3.head(4)
# Out:
#   customer_state customer_state_full product_category_name_english  \
# 0             AC                Acre               furniture_decor
# 1             AC                Acre                sports_leisure
# 2             AC                Acre                 health_beauty
# 3             AL             Alagoas                 health_beauty
#
#    total_payment  rank     region
# 0        5261.23     1      North
# 1        2071.54     2      North
# 2        2067.62     3      North
# 3       14741.33     1  Northeast

# %%
# Get sum for total_payment for each grouped region and product category
regional_data = df3.groupby(['region', 'product_category_name_english'])['total_payment'].sum().reset_index()
regional_data
# Out:
#           region product_category_name_english  total_payment
# 0   Central-West                          auto       76181.07
# 1   Central-West         computers_accessories       38634.68
# 2   Central-West                  garden_tools       42451.17
# 3   Central-West                 health_beauty       73388.20
# 4   Central-West                    housewares       55119.09
# 5   Central-West        signaling_and_security       19457.04
# 6   Central-West                sports_leisure       51226.78
# 7          North                bed_bath_table        3432.29
# 8          North         computers_accessories        9995.80
# 9          North               furniture_decor       26190.94
# 10         North                  garden_tools        2267.80
# 11         North                 health_beauty       54666.13
# 12         North                sports_leisure       16814.21
# 13         North                 watches_gifts       37836.02
# 14     Northeast                          auto       20026.82
# 15     Northeast                bed_bath_table       10397.57
# 16     Northeast         computers_accessories      139747.60
# 17     Northeast               furniture_decor        8544.12
# 18     Northeast                  garden_tools        7908.35
# 19     Northeast                 health_beauty      259436.40
# 20     Northeast        signaling_and_security       17069.76
# 21     Northeast                sports_leisure      100101.01
# 22     Northeast                     telephony        6783.72
# 23     Northeast                 watches_gifts      100859.21
# 24         South                bed_bath_table       93423.36
# 25         South         computers_accessories      171942.04
# 26         South               furniture_decor      267653.18
# 27         South                sports_leisure      140632.01
# 28         South                 watches_gifts       85401.59
# 29     Southeast                bed_bath_table     1250610.88
# 30     Southeast         computers_accessories      983034.93
# 31     Southeast               fixed_telephony       30248.54
# 32     Southeast                 health_beauty      800844.86
# 33     Southeast                 watches_gifts      240279.04

# %%
# get top 3 product categories per region (divide the states into Central West, North, Northeast, South, Southest)
regional_top3 = regional_data.sort_values(['region', 'total_payment'], ascending=[True, False]).groupby('region').head(3)
regional_top3
# Out:
#           region product_category_name_english  total_payment
# 0   Central-West                          auto       76181.07
# 3   Central-West                 health_beauty       73388.20
# 4   Central-West                    housewares       55119.09
# 11         North                 health_beauty       54666.13
# 13         North                 watches_gifts       37836.02
# 9          North               furniture_decor       26190.94
# 19     Northeast                 health_beauty      259436.40
# 16     Northeast         computers_accessories      139747.60
# 23     Northeast                 watches_gifts      100859.21
# 26         South               furniture_decor      267653.18
# 25         South         computers_accessories      171942.04
# 27         South                sports_leisure      140632.01
# 29     Southeast                bed_bath_table     1250610.88
# 30     Southeast         computers_accessories      983034.93
# 32     Southeast                 health_beauty      800844.86

# %%
# Visualize 

regions = regional_top3['region'].unique()
all_categories = regional_top3['product_category_name_english'].unique()
fig, axes = plt.subplots(2,3, figsize = (18,10))
colors = plt.cm.tab20(range(len(all_categories)))  # tab20 gives 20 distinct colors
category_colors = dict(zip(all_categories, colors))


axes = axes.flatten()

for index, region in enumerate(regions):
    region_data = regional_top3[regional_top3['region'] == region]
    bar_colors = [category_colors[cat] for cat in region_data['product_category_name_english']]
    #axes[index].barh(region_data['product_category_name_english'], region_data['total_payment'], color='steelblue')
    axes[index].barh(region_data['product_category_name_english'], region_data['total_payment'], color=bar_colors) 
    axes[index].set_title(f'{region} Region', fontsize=13, fontweight='bold')
    axes[index].tick_params(axis='both', labelsize=10)
    axes[index].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x/1000)}K'))
axes[-1].axis('off')
plt.suptitle('Top 3 Product Categories by Region', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Now I visualize the customer segments for 02. cohort_analysis

# %%
customer_segments = pd.read_csv('/Users/anuka/Documents/python_projects/october/data/customer_segemnts_new.csv')

# %%
customer_segments.head(5)
# Out:
#                   segment  customer_count  customer_pct  total_revenue  \
# 0       Mid-Value at Risk           15472          16.0        2601098
# 1             VIP at risk            3871           4.0        2437778
# 2  Mid-Value Cooling Down           11659          12.1        1915424
# 3        VIP Cooling Down            2716           2.8        1691807
# 4       Low Value Churned           28765          29.8        1546042
#
#    revenue_pct  avg_spent  avg_items  avg_recency_days
# 0         19.7     168.12        1.2             412.5
# 1         18.4     629.75        1.4             421.4
# 2         14.5     164.29        1.2             195.6
# 3         12.8     622.90        1.4             193.9
# 4         11.7      53.75        1.1             415.4

# %%
fig = px.scatter(customer_segments, x = 'avg_recency_days',y = 'avg_spent',size='customer_count',color = 'segment',
color_discrete_sequence=px.colors.qualitative.Bold, text = 'segment', hover_data = ['revenue_pct', 'customer_pct', 'total_revenue'], title = 'Customer Segmentation: Value vs. Engagement Risk')

fig.update_traces(textposition ='top center', textfont_size = 8)
fig.show()

# %%
customer_segments_data = pd.read_csv('/Users/anuka/Documents/python_projects/october/data/customer_segs.csv')

# %%
#customer_segments_data.head(10)
print(customer_segments_data.value_counts())
# Out:
# customer_id                       total_order_items  recency_days  total_spent  segment
# 00012a2ce6f8dcda20d059ce98491703  1                  336.327477    89.80        Low-Value Churned         1
# aa5e0a0c36015d39de864189a2b00b09  1                  63.177616     76.00        Low-Value Recent          1
# aa6190994371836fc1d4596edd827abd  1                  292.109745    210.00       Mid-Value At Risk         1
# aa606152f23a5fa9ba3d0b87f7a492e8  1                  273.028854    55.00        Low-Value Churned         1
# aa601b3c45980c0918042d5ca7a25054  1                  215.292234    49.99        Others                    1
#                                                                                                          ..
# 5584b1ace8b18cc156ce51b989fd2958  1                  168.216852    60.00        Others                    1
# 558499c2027ec01d530fb975ce2e5b2f  1                  557.401956    17.90        Low-Value Churned         1
# 55846a9bb9076de56da44e430349ad1a  1                  181.034259    104.00       Mid-Value Cooling Down    1
# 55840ff4caf1d80ac296d0b1ac968b53  5                  155.548831    179.50       Mid-Value Cooling Down    1
# ffffa3172527f765de70084a7e53aae8  2                  409.504491    21.80        Low-Value Churned         1
# Name: count, Length: 96478, dtype: int64

# %%
customer_segments_data['recency_days'].describe()
# Out:
# count    96478.000000
# mean       288.021158
# std        152.838560
# min         48.374572
# 25%        164.211956
# 50%        269.176562
# 75%        397.624731
# max        761.488449
# Name: recency_days, dtype: float64

# %%
percentiles = customer_segments_data['recency_days'].quantile([0.25, 0.33, 0.50, 0.66, 0.75])
print('Recency percentiles:')
print(percentiles)
# Out:
# Recency percentiles:
# 0.25    164.211956
# 0.33    197.399138
# 0.50    269.176562
# 0.66    337.197493
# 0.75    397.624731
# Name: recency_days, dtype: float64

# %%
threshold_33 = customer_segments_data['recency_days'].quantile(0.33)
threshold_66 = customer_segments_data['recency_days'].quantile(0.66)


print(f"\nThirds Approach:")
print(f"Active: ≤ {threshold_33:.0f} days (top 33%)")
print(f"Cooling: {threshold_33:.0f} - {threshold_66:.0f} days (middle 33%)")
print(f"At Risk: > {threshold_66:.0f} days (bottom 33%)")
# Out:
# Thirds Approach:
# Active: ≤ 197 days (top 33%)
# Cooling: 197 - 337 days (middle 33%)
# At Risk: > 337 days (bottom 33%)

# %%
threshold_25 = customer_segments_data['recency_days'].quantile(0.25)
threshold_75 = customer_segments_data['recency_days'].quantile(0.75)

print(f"\nQuartiles Approach:")
print(f"Active: ≤ {threshold_25:.0f} days (top 25%)")
print(f"Cooling: {threshold_25:.0f} - {threshold_75:.0f} days (middle 50%)")
print(f"At Risk: > {threshold_75:.0f} days (bottom 25%)")
# Out:
# Quartiles Approach:
# Active: ≤ 164 days (top 25%)
# Cooling: 164 - 398 days (middle 50%)
# At Risk: > 398 days (bottom 25%)

# %%
customer_segments_data['total_spent'].describe()
# Out:
# count    96478.000000
# mean       137.041586
# std        209.045198
# min          0.850000
# 25%         45.900000
# 50%         86.575000
# 75%        149.900000
# max      13440.000000
# Name: total_spent, dtype: float64

# %%
threshold_25_spent = customer_segments_data['total_spent'].quantile(0.25)
threshold_75_spent = customer_segments_data['total_spent'].quantile(0.75)

# %%
print(f"\nQuartiles Approach:")
print(f"Active: ≤ {threshold_25_spent:.0f} dollars (top 25%)")
print(f"Cooling: {threshold_25_spent:.0f} - {threshold_75_spent:.0f} dollars (middle 50%)")
print(f"At Risk: > {threshold_75_spent:.0f} dollars (bottom 25%)")
# Out:
# Quartiles Approach:
# Active: ≤ 46 dollars (top 25%)
# Cooling: 46 - 150 dollars (middle 50%)
# At Risk: > 150 dollars (bottom 25%)

# %% [markdown]
# ### 3. What are the top categories in each state? -> For simplicity, visualizing Top 3 categories per state

# %%
top_three = pd.read_csv('/Users/anuka/Documents/python_projects/october/data/product_by_state.csv')

top_three.head(10)
# Out:
#   customer_state customer_state_full product_category_name_english  \
# 0             AC                Acre               furniture_decor
# 1             AC                Acre                sports_leisure
# 2             AC                Acre                 health_beauty
# 3             AL             Alagoas                 health_beauty
# 4             AL             Alagoas         computers_accessories
# 5             AL             Alagoas                 watches_gifts
# 6             AM            Amazonas         computers_accessories
# 7             AM            Amazonas                 health_beauty
# 8             AM            Amazonas                  garden_tools
# 9             AP               Amapá         computers_accessories
#
#    total_payment  rank
# 0        5261.23     1
# 1        2071.54     2
# 2        2067.62     3
# 3       14741.33     1
# 4       14280.47     2
# 5       13249.34     3
# 6        5866.85     1
# 7        4566.70     2
# 8        2267.80     3
# 9        4128.95     1

# %%
top_three['product_category'].unique()
# Out:
# array(['furniture_decor', 'sports_leisure', 'health_beauty',
#        'computers_accessories', 'watches_gifts', 'garden_tools',
#        'bed_bath_table', 'fixed_telephony', 'auto', 'housewares',
#        'signaling_and_security', 'telephony'], dtype=object)

# %%
top_three['product_category_name_english'].unique()
# Out:
# array(['furniture_decor', 'sports_leisure', 'health_beauty',
#        'computers_accessories', 'watches_gifts', 'garden_tools',
#        'bed_bath_table', 'fixed_telephony', 'auto', 'housewares',
#        'signaling_and_security', 'telephony'], dtype=object)

# %%
top_three.head(5)
# Out:
#   customer_state customer_state_full product_category_name_english  \
# 0             AC                Acre               furniture_decor
# 1             AC                Acre                sports_leisure
# 2             AC                Acre                 health_beauty
# 3             AL             Alagoas                 health_beauty
# 4             AL             Alagoas         computers_accessories
#
#    total_payment  rank
# 0        5261.23     1
# 1        2071.54     2
# 2        2067.62     3
# 3       14741.33     1
# 4       14280.47     2

# %%
top_three_states_one = top_three[top_three['rank'] == 1]
top_three_states = top_three_states_one.nlargest(10, 'total_payment')
top_three_states
# Out:
#    customer_state customer_state_full product_category_name_english  \
# 75             SP           São Paulo                bed_bath_table
# 54             RJ      Rio de Janeiro                bed_bath_table
# 30             MG        Minas Gerais                bed_bath_table
# 51             PR              Paraná               furniture_decor
# 66             RS   Rio Grande do Sul         computers_accessories
# 12             BA               Bahia                 health_beauty
# 69             SC      Santa Catarina         computers_accessories
# 24             GO               Goiás                          auto
# 45             PE          Pernambuco                 health_beauty
# 15             CE               Ceará                 health_beauty
#
#     total_payment  rank
# 75      756727.97     1
# 54      242431.81     1
# 30      216969.38     1
# 51      114060.51     1
# 66      108472.88     1
# 12       65382.14     1
# 69       63469.16     1
# 24       57732.00     1
# 45       55903.70     1
# 15       45615.12     1

# %%
plt.figure(figsize=(12,6))
sns.barplot(data = top_three_states,
            y = 'customer_state_full',
            x = 'total_payment',
            hue = 'product_category_name_english',
            palette = 'Set3',
            dodge=False)
# Out:
# <Axes: xlabel='total_payment', ylabel='customer_state_full'>

# %% [markdown]
# ### Now I want to visualize all the states by total_payment

# %%
# Run these and share the output:
print(top_three.columns.tolist())
print(top_three['customer_state_full'].unique())

top_three_rank_one = top_three[top_three['rank'] == 1]
print(f"Number of states: {top_three_rank_one.shape[0]}")
top_three_rank_one.head()
# Out:
# ['customer_state', 'customer_state_full', 'product_category_name_english', 'total_payment', 'rank']
# ['Acre' 'Alagoas' 'Amazonas' 'Amapá' 'Bahia' 'Ceará' 'Federal District'
#  'Espírito Santo' 'Goiás' 'Maranhão' 'Minas Gerais' 'Mato Grosso do Sul'
#  'Mato Grosso' 'Pará' 'Paraíba' 'Pernambuco' 'Piauí' 'Paraná'
#  'Rio de Janeiro' 'Rio Grande do Norte' 'Rondônia' nan 'Rio Grande do Sul'
#  'Santa Catarina' 'Sergipe' 'São Paulo' 'Tocantins']
# Number of states: 27
#    customer_state customer_state_full product_category_name_english  \
# 0              AC                Acre               furniture_decor
# 3              AL             Alagoas                 health_beauty
# 6              AM            Amazonas         computers_accessories
# 9              AP               Amapá         computers_accessories
# 12             BA               Bahia                 health_beauty
#
#     total_payment  rank
# 0         5261.23     1
# 3        14741.33     1
# 6         5866.85     1
# 9         4128.95     1
# 12       65382.14     1

# %%
# Prepare data
top_three_rank_one = top_three[top_three['rank'] == 1].sort_values('total_payment', ascending=True)

# Create plot
plt.figure(figsize=(10, 12))
sns.barplot(
    data=top_three_rank_one,
    y='customer_state_full',
    x='total_payment',
    hue='product_category_name_english',
    palette='Set3',
    dodge=False
)

plt.xlabel('Total Payment (R$)', fontsize=12)
plt.ylabel('State', fontsize=12)
plt.title('Top Product Category by Brazilian State (Ranked by Revenue)', fontsize=14)
plt.legend(title='Top Category', bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=9)
plt.tight_layout()
plt.show()

# %%
top_three_states_per_category = pd.read_csv('/Users/anuka/Documents/python_projects/october/data/top_three_per_category.csv')
top_three_states_per_category.head(10)
# Out:
#   product_category_name_english customer_state customer_state_full  \
# 0    agro_industry_and_commerce             MG        Minas Gerais
# 1    agro_industry_and_commerce             SP           São Paulo
# 2    agro_industry_and_commerce             RJ      Rio de Janeiro
# 3              air_conditioning             SP           São Paulo
# 4              air_conditioning             RJ      Rio de Janeiro
# 5              air_conditioning             MG        Minas Gerais
# 6                           art             SP           São Paulo
# 7                           art             RJ      Rio de Janeiro
# 8                           art             MG        Minas Gerais
# 9         arts_and_craftmanship             SP           São Paulo
#
#    total_payment  rank  pct_of_category
# 0       44016.72     1            38.07
# 1       30871.12     2            26.70
# 2        9770.67     3             8.45
# 3       42274.58     1            47.58
# 4       23252.50     2            26.17
# 5        6258.30     3             7.04
# 6       16204.96     1            56.86
# 7        3725.10     2            13.07
# 8        1699.96     3             5.97
# 9        1189.39     1            51.13

# %% [markdown]
# ### Top 3 states for the Top 10 highest revenue product (not included in Github)

# %%
# Get top 10 categories by total revenue
top_categories = top_three_states_per_category.groupby('product_category_name_english')['total_payment'].sum().nlargest(10).index

# Filter to only these categories, top 3 states each
top_three_filtered = top_three_states_per_category[
    top_three_states_per_category['product_category_name_english'].isin(top_categories)
]

# Get rank within each category
top_three_filtered = top_three_filtered.sort_values(['product_category_name_english', 'total_payment'], ascending=[True, False])
top_three_filtered['rank'] = top_three_filtered.groupby('product_category_name_english').cumcount() + 1
top_three_filtered = top_three_filtered[top_three_filtered['rank'] <= 3]

# Visualize
plt.figure(figsize=(14, 8))
sns.barplot(
    data=top_three_filtered,
    y='product_category_name_english',
    x='total_payment',
    hue='customer_state',
    palette='Set3'
)

plt.xlabel('Total Payment (R$)', fontsize=12)
plt.ylabel('Product Category', fontsize=12)
plt.title('Top 3 States for the 10 Highest-Revenue Product Categories', fontsize=14)
plt.legend(title='State', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 05. Which categories show the fastest revenue growth month-over-month?

# %%
monthly_diff = pd.read_csv('/Users/anuka/Documents/python_projects/october/data/monthly_diff_analysis.csv')
monthly_diff.head(100)
# Out:
#    product_category_name_english order_purchase_timestamp  year  month  \
# 0     agro_industry_and_commerce      2017-01-23 07:03:04  2017      1
# 1     agro_industry_and_commerce      2017-02-13 13:00:36  2017      2
# 2     agro_industry_and_commerce      2017-03-17 15:57:36  2017      3
# 3     agro_industry_and_commerce      2017-05-28 23:01:27  2017      5
# 4     agro_industry_and_commerce      2017-06-26 13:44:08  2017      6
# ..                           ...                      ...   ...    ...
# 95                          auto      2017-11-15 13:47:34  2017     11
# 96                          auto      2017-12-02 14:08:33  2017     12
# 97                          auto      2018-01-07 19:59:42  2018      1
# 98                          auto      2018-02-01 07:47:34  2018      2
# 99                          auto      2018-03-21 14:15:20  2018      3
#
#     monthly_revenue
# 0            169.18
# 1            331.10
# 2            110.69
# 3           1763.74
# 4           1422.05
# ..              ...
# 95         45390.34
# 96         52504.86
# 97         49737.02
# 98         51586.49
# 99         57698.30
#
# [100 rows x 5 columns]

# %%
# Create a year-month column for easier analysis
monthly_diff['year_month'] = monthly_diff['year'].astype(str) + '-' + monthly_diff['month'].astype(str).str.zfill(2)

# What's the full date range?
print(f"Start: {monthly_diff['year_month'].min()}")
print(f"End: {monthly_diff['year_month'].max()}")

# How many unique year-month combinations?
unique_months = monthly_diff['year_month'].nunique()
print(f"Total unique months: {unique_months}")
# Out:
# Start: 2016-10
# End: 2018-08
# Total unique months: 22

# %%
monthly_revenue = monthly_diff.groupby(['product_category_name_english', 'year', 'month'])['monthly_revenue'].sum().reset_index()

# %%
monthly_revenue.head(10)
monthly_revenue.columns = ['category', 'year', 'month',  'monthly_revenue']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 monthly_revenue.head(10)
#       2 monthly_revenue.columns = ['category', 'year', 'month',  'monthly_revenue']
#
# NameError: name 'monthly_revenue' is not defined

# %%
monthly_revenue['year_month'] = monthly_revenue['year'].astype(str) + "-" + monthly_revenue['month'].astype(str).str.zfill(2)
monthly_revenue = monthly_revenue.sort_values(['category', 'year_month'])
monthly_revenue
# Out:
#                         category  year  month  monthly_revenue year_month
# 0     agro_industry_and_commerce  2017      1           169.18    2017-01
# 1     agro_industry_and_commerce  2017      2           331.10    2017-02
# 2     agro_industry_and_commerce  2017      3           110.69    2017-03
# 3     agro_industry_and_commerce  2017      5          1763.74    2017-05
# 4     agro_industry_and_commerce  2017      6          1422.05    2017-06
# ...                          ...   ...    ...              ...        ...
# 1237               watches_gifts  2018      4        106336.85    2018-04
# 1238               watches_gifts  2018      5        145869.23    2018-05
# 1239               watches_gifts  2018      6        105922.17    2018-06
# 1240               watches_gifts  2018      7        109159.53    2018-07
# 1241               watches_gifts  2018      8         82634.64    2018-08
#
# [1242 rows x 5 columns]

# %%
# how many unique months does each category have?
category_month_count = monthly_revenue.groupby('category')['year_month'].count()
print("Distribution months per category:")
print(category_month_count.describe())
print()

complete_categories = category_month_count[category_month_count == 22]
print(f"Categories with all 22 months: {len(complete_categories)} out of {len(category_month_count)}")
print()

substantial_categories = category_month_count[category_month_count >= 12]
print(f"Categories with 12+ months: {len(substantial_categories)}")
# Out:
# Distribution months per category:
# count    71.000000
# mean     17.492958
# std       4.572818
# min       2.000000
# 25%      14.500000
# 50%      20.000000
# 75%      21.000000
# max      22.000000
# Name: year_month, dtype: float64
#
# Categories with all 22 months: 1 out of 71
#
# Categories with 12+ months: 62

# %%
## Use categories for 12 months minimum 
susbtantial_cats = substantial_categories.index
print(f"Categories kept: {len(susbtantial_cats)} out of {monthly_revenue['category'].nunique()}")
# Out:
# Categories kept: 62 out of 71

# %%
#Now time to filter

monthly_revenue['category'].isin(susbtantial_cats)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1237    True
# 1238    True
# 1239    True
# 1240    True
# 1241    True
# Name: category, Length: 1242, dtype: bool

# %%
# Use the mask 

mask = monthly_revenue['category'].isin(susbtantial_cats)
monthly_revenue_filtered = monthly_revenue[mask]
monthly_revenue_filtered = monthly_revenue_filtered.sort_values(['category', 'year_month'])
monthly_revenue_filtered
# Out:
#                         category  year  month  monthly_revenue year_month
# 0     agro_industry_and_commerce  2017      1           169.18    2017-01
# 1     agro_industry_and_commerce  2017      2           331.10    2017-02
# 2     agro_industry_and_commerce  2017      3           110.69    2017-03
# 3     agro_industry_and_commerce  2017      5          1763.74    2017-05
# 4     agro_industry_and_commerce  2017      6          1422.05    2017-06
# ...                          ...   ...    ...              ...        ...
# 1237               watches_gifts  2018      4        106336.85    2018-04
# 1238               watches_gifts  2018      5        145869.23    2018-05
# 1239               watches_gifts  2018      6        105922.17    2018-06
# 1240               watches_gifts  2018      7        109159.53    2018-07
# 1241               watches_gifts  2018      8         82634.64    2018-08
#
# [1172 rows x 5 columns]

# %%
print('First 15 rows after sorting: ')
print(monthly_revenue_filtered[['category', 'year_month', 'monthly_revenue']].head(15))
# Out:
# First 15 rows after sorting:
#                       category year_month  monthly_revenue
# 0   agro_industry_and_commerce    2017-01           169.18
# 1   agro_industry_and_commerce    2017-02           331.10
# 2   agro_industry_and_commerce    2017-03           110.69
# 3   agro_industry_and_commerce    2017-05          1763.74
# 4   agro_industry_and_commerce    2017-06          1422.05
# 5   agro_industry_and_commerce    2017-07          1199.47
# 6   agro_industry_and_commerce    2017-08           898.40
# 7   agro_industry_and_commerce    2017-09          2967.01
# 8   agro_industry_and_commerce    2017-10          3558.43
# 9   agro_industry_and_commerce    2017-11         45878.42
# 10  agro_industry_and_commerce    2017-12          6796.16
# 11  agro_industry_and_commerce    2018-01          6761.99
# 12  agro_industry_and_commerce    2018-02         10835.68
# 13  agro_industry_and_commerce    2018-03          5909.15
# 14  agro_industry_and_commerce    2018-04          4783.66

# %% [markdown]
# #### Shifting the values to the next one using shift(1) method

# %%
monthly_revenue_filtered['previous_month_revenue'] = monthly_revenue_filtered.groupby('category')['monthly_revenue'].shift(1)
print('\nFirst 20 rows with previous month revenue:')
print(monthly_revenue_filtered[['category', 'year_month', 'monthly_revenue', 'previous_month_revenue']].head(30))
# Out:
# First 20 rows with previous month revenue:
#                       category year_month  monthly_revenue  \
# 0   agro_industry_and_commerce    2017-01           169.18
# 1   agro_industry_and_commerce    2017-02           331.10
# 2   agro_industry_and_commerce    2017-03           110.69
# 3   agro_industry_and_commerce    2017-05          1763.74
# 4   agro_industry_and_commerce    2017-06          1422.05
# 5   agro_industry_and_commerce    2017-07          1199.47
# 6   agro_industry_and_commerce    2017-08           898.40
# 7   agro_industry_and_commerce    2017-09          2967.01
# 8   agro_industry_and_commerce    2017-10          3558.43
# 9   agro_industry_and_commerce    2017-11         45878.42
# 10  agro_industry_and_commerce    2017-12          6796.16
# 11  agro_industry_and_commerce    2018-01          6761.99
# 12  agro_industry_and_commerce    2018-02         10835.68
# 13  agro_industry_and_commerce    2018-03          5909.15
# 14  agro_industry_and_commerce    2018-04          4783.66
# 15  agro_industry_and_commerce    2018-05          3433.22
# 16  agro_industry_and_commerce    2018-06          3843.05
# 17  agro_industry_and_commerce    2018-07          7613.44
# 18  agro_industry_and_commerce    2018-08          7357.40
# 19            air_conditioning    2016-10          3872.83
# 20            air_conditioning    2017-01          1103.79
# 21            air_conditioning    2017-02          2688.34
# 22            air_conditioning    2017-03          4541.62
# 23            air_conditioning    2017-04          3222.06
# 24            air_conditioning    2017-05          1282.55
# 25            air_conditioning    2017-06          3631.02
# 26            air_conditioning    2017-07          1493.13
# 27            air_conditioning    2017-08          7655.69
# 28            air_conditioning    2017-09          1782.09
# 29            air_conditioning    2017-10          4697.62
#
#     previous_month_revenue
# 0                      NaN
# 1                   169.18
# 2                   331.10
# 3                   110.69
# 4                  1763.74
# 5                  1422.05
# 6                  1199.47
# 7                   898.40
# 8                  2967.01
# 9                  3558.43
# 10                45878.42
# 11                 6796.16
# 12                 6761.99
# 13                10835.68
# 14                 5909.15
# 15                 4783.66
# 16                 3433.22
# 17                 3843.05
# 18                 7613.44
# 19                     NaN
# 20                 3872.83
# 21                 1103.79
# 22                 2688.34
# 23                 4541.62
# 24                 3222.06
# 25                 1282.55
# 26                 3631.02
# 27                 1493.13
# 28                 7655.69
# 29                 1782.09

# %% [markdown]
# ### Calculate Month-over-Month Growth %

# %%
monthly_revenue_filtered['mon_growth_pct'] = ((monthly_revenue_filtered['monthly_revenue'] - monthly_revenue_filtered['previous_month_revenue'])/monthly_revenue_filtered['previous_month_revenue'])*100
print('\nFirst 20 rows with growth %:')
monthly_revenue_filtered.head(50)
# Out:
# First 20 rows with growth %:
#                       category  year  month  monthly_revenue year_month  \
# 0   agro_industry_and_commerce  2017      1           169.18    2017-01
# 1   agro_industry_and_commerce  2017      2           331.10    2017-02
# 2   agro_industry_and_commerce  2017      3           110.69    2017-03
# 3   agro_industry_and_commerce  2017      5          1763.74    2017-05
# 4   agro_industry_and_commerce  2017      6          1422.05    2017-06
# 5   agro_industry_and_commerce  2017      7          1199.47    2017-07
# 6   agro_industry_and_commerce  2017      8           898.40    2017-08
# 7   agro_industry_and_commerce  2017      9          2967.01    2017-09
# 8   agro_industry_and_commerce  2017     10          3558.43    2017-10
# 9   agro_industry_and_commerce  2017     11         45878.42    2017-11
# 10  agro_industry_and_commerce  2017     12          6796.16    2017-12
# 11  agro_industry_and_commerce  2018      1          6761.99    2018-01
# 12  agro_industry_and_commerce  2018      2         10835.68    2018-02
# 13  agro_industry_and_commerce  2018      3          5909.15    2018-03
# 14  agro_industry_and_commerce  2018      4          4783.66    2018-04
# 15  agro_industry_and_commerce  2018      5          3433.22    2018-05
# 16  agro_industry_and_commerce  2018      6          3843.05    2018-06
# 17  agro_industry_and_commerce  2018      7          7613.44    2018-07
# 18  agro_industry_and_commerce  2018      8          7357.40    2018-08
# 19            air_conditioning  2016     10          3872.83    2016-10
# 20            air_conditioning  2017      1          1103.79    2017-01
# 21            air_conditioning  2017      2          2688.34    2017-02
# 22            air_conditioning  2017      3          4541.62    2017-03
# 23            air_conditioning  2017      4          3222.06    2017-04
# 24            air_conditioning  2017      5          1282.55    2017-05
# 25            air_conditioning  2017      6          3631.02    2017-06
# 26            air_conditioning  2017      7          1493.13    2017-07
# 27            air_conditioning  2017      8          7655.69    2017-08
# 28            air_conditioning  2017      9          1782.09    2017-09
# 29            air_conditioning  2017     10          4697.62    2017-10
# 30            air_conditioning  2017     11          6813.50    2017-11
# 31            air_conditioning  2017     12           722.34    2017-12
# 32            air_conditioning  2018      1          8126.78    2018-01
# 33            air_conditioning  2018      2          3518.95    2018-02
# 34            air_conditioning  2018      3          3532.05    2018-03
# 35            air_conditioning  2018      4          4310.24    2018-04
# 36            air_conditioning  2018      5          2711.01    2018-05
# 37            air_conditioning  2018      6         13923.04    2018-06
# 38            air_conditioning  2018      7          3701.34    2018-07
# 39            air_conditioning  2018      8          5519.73    2018-08
# 40                         art  2017      3           255.00    2017-03
# 41                         art  2017      4           147.17    2017-04
# 42                         art  2017      5          7302.75    2017-05
# 43                         art  2017      6           285.35    2017-06
# 44                         art  2017      7           424.90    2017-07
# 45                         art  2017      8           317.06    2017-08
# 46                         art  2017      9           435.85    2017-09
# 47                         art  2017     10           400.45    2017-10
# 48                         art  2017     11            92.78    2017-11
# 49                         art  2017     12           191.76    2017-12
#
#     previous_month_revenue  mon_growth_pct
# 0                      NaN             NaN
# 1                   169.18       95.708713
# 2                   331.10      -66.569012
# 3                   110.69     1493.405005
# 4                  1763.74      -19.373037
# 5                  1422.05      -15.652052
# 6                  1199.47      -25.100253
# 7                   898.40      230.254898
# 8                  2967.01       19.933199
# 9                  3558.43     1189.288254
# 10                45878.42      -85.186587
# 11                 6796.16       -0.502784
# 12                 6761.99       60.243952
# 13                10835.68      -45.465813
# 14                 5909.15      -19.046563
# 15                 4783.66      -28.230267
# 16                 3433.22       11.937190
# 17                 3843.05       98.109314
# 18                 7613.44       -3.363000
# 19                     NaN             NaN
# 20                 3872.83      -71.499136
# 21                 1103.79      143.555386
# 22                 2688.34       68.937709
# 23                 4541.62      -29.054831
# 24                 3222.06      -60.194720
# 25                 1282.55      183.109430
# 26                 3631.02      -58.878497
# 27                 1493.13      412.727626
# 28                 7655.69      -76.722020
# 29                 1782.09      163.601726
# 30                 4697.62       45.041532
# 31                 6813.50      -89.398400
# 32                  722.34     1025.062990
# 33                 8126.78      -56.699332
# 34                 3518.95        0.372270
# 35                 3532.05       22.032248
# 36                 4310.24      -37.103038
# 37                 2711.01      413.573908
# 38                13923.04      -73.415720
# 39                 3701.34       49.127883
# 40                     NaN             NaN
# 41                  255.00      -42.286275
# 42                  147.17     4862.118638
# 43                 7302.75      -96.092568
# 44                  285.35       48.904854
# 45                  424.90      -25.380089
# 46                  317.06       37.466095
# 47                  435.85       -8.122060
# 48                  400.45      -76.831065
# 49                   92.78      106.682475

# %%
growth_data = monthly_revenue_filtered[monthly_revenue_filtered['previous_month_revenue'].notna()].copy()

# %%
print(f"Growth rate statistics:")
print(growth_data['mon_growth_pct'].describe())

print(f"\nRows before cleaning: {len(monthly_revenue_filtered)}")
print(f"Rows after removing NaN: {len(growth_data)}")
# Out:
# Growth rate statistics:
# count     1110.000000
# mean       101.014650
# std        613.443223
# min        -98.553572
# 25%        -27.697545
# 50%          9.517776
# 75%         73.929068
# max      13598.114169
# Name: mon_growth_pct, dtype: float64
#
# Rows before cleaning: 1172
# Rows after removing NaN: 1110

# %% [markdown]
# This growth rate looks very unreasonable, hence I could not realistically calculate the growth rate. It is more like volatility from low base numbers. First, finding the extreme growth number categories.

# %%
len(growth_data)
# Out:
# 1110

# %%
# Only calculate growth when previous month had meaningful revenue (e.g >500 dollars)
# This is due to some months have low revenue (e.g 92.78 dollars art category in year 2017 december)
growth_data_filtered = growth_data[growth_data['previous_month_revenue']>500].copy()
print(f"\nRows after filtering low vase values: {len(growth_data_filtered)}")
print(growth_data_filtered['mon_growth_pct'].describe())
# Out:
# Rows after filtering low vase values: 925
# count     925.000000
# mean       41.971129
# std       180.348293
# min       -98.553572
# 25%       -28.269153
# 50%         5.458241
# 75%        51.742779
# max      2636.154113
# Name: mon_growth_pct, dtype: float64

# %% [markdown]
# Use Median growth instead of Mean growth

# %%
median_growth = growth_data_filtered.groupby('category')['mon_growth_pct'].median().sort_values(ascending=False)
median_growth.head(10)
# Out:
# category
# construction_tools_safety          31.261121
# watches_gifts                      28.540595
# construction_tools_lights          27.053887
# construction_tools_construction    26.845465
# computers                          26.310429
# pet_shop                           25.815803
# home_appliances                    25.430874
# telephony                          17.715432
# office_furniture                   16.504929
# luggage_accessories                15.895195
# Name: mon_growth_pct, dtype: float64

# %%
median_growth.describe()
# Out:
# count    61.000000
# mean     -3.113159
# std      26.975904
# min     -90.489224
# 25%      -8.256576
# 50%       5.407304
# 75%      11.629883
# max      31.261121
# Name: mon_growth_pct, dtype: float64

# %%
print("TOP 10 FASTEST Growing (by median):")
print(median_growth.head(10))

print('\nBOTTOM 10 (declining):')
print(median_growth.tail(10))
# Out:
# TOP 10 FASTEST Growing (by median):
# category
# construction_tools_safety          31.261121
# watches_gifts                      28.540595
# construction_tools_lights          27.053887
# construction_tools_construction    26.845465
# computers                          26.310429
# pet_shop                           25.815803
# home_appliances                    25.430874
# telephony                          17.715432
# office_furniture                   16.504929
# luggage_accessories                15.895195
# Name: mon_growth_pct, dtype: float64
#
# BOTTOM 10 (declining):
# category
# market_place              -21.080330
# drinks                    -27.951883
# fashion_underwear_beach   -37.531524
# cine_photo                -41.096544
# tablets_printing_image    -52.753246
# music                     -58.347954
# dvds_blu_ray              -70.892449
# party_supplies            -71.007858
# fashio_female_clothing    -74.229658
# fashion_sport             -90.489224
# Name: mon_growth_pct, dtype: float64

# %%
# Average (mean) growth per category
mean_growth = growth_data_filtered.groupby('category')['mon_growth_pct'].mean().sort_values(ascending=False)

print("\n=== TOP 10 BY AVERAGE (MEAN) MON GROWTH ===")
print(mean_growth.head(10))
# Out:
# === TOP 10 BY AVERAGE (MEAN) MON GROWTH ===
# category
# drinks                                     229.219838
# fixed_telephony                            156.847613
# signaling_and_security                     140.074298
# costruction_tools_tools                    115.581390
# air_conditioning                            98.708851
# agro_industry_and_commerce                  91.189763
# computers                                   89.444528
# furniture_living_room                       77.743030
# kitchen_dining_laundry_garden_furniture     74.532717
# garden_tools                                72.723592
# Name: mon_growth_pct, dtype: float64

# %% [markdown]
# ### Now it is time to visualize. I choose median growth here, since mean shows very volatile numbers with occasional spikes rather than sustained growth

# %%
top_10_growth = median_growth.head(10)
bottom_10_growth = median_growth.tail(10)

combined_growth = pd.concat([top_10_growth, bottom_10_growth])

# %%
fig,ax = plt.subplots(figsize=(12,10))
colors = ['green' if x>0 else 'red' for x in combined_growth.values]
bars = ax.barh(range(len(combined_growth)), combined_growth.values, color=colors, alpha=0.7)

ax.set_yticks(range(len(combined_growth)))
ax.set_yticklabels(combined_growth.index, fontsize=10)

ax.set_xlabel('Median Month-over-Month Growth(%)', fontsize=12)
ax.set_title('Top 10 Fastest Growing vs Bottom 10 Declining Product Categories\n(Median Monthly Growth Rate)', fontsize=14, 
fontweight ='bold', pad=20)
ax.axvline(x=0, color='black', linewidth=0.8, linestyle='--')


for i in range(len(combined_growth)):
    bar = bars[i]
    value = combined_growth.values[i]
    category_name = combined_growth.index[i]

    label = f'{value:.1f}%'

    if value > 0:
        x_position = value+0.3
        ax.text(x_position, i, label, va='center', fontsize=9)
    else:
        x_position = value -0.005
        ax.text(x_position, i, label, va='center', ha='right', fontsize=9)

# %%
top_10_growth
# Out:
# category
# construction_tools_safety          31.261121
# watches_gifts                      28.540595
# construction_tools_lights          27.053887
# construction_tools_construction    26.845465
# computers                          26.310429
# pet_shop                           25.815803
# home_appliances                    25.430874
# telephony                          17.715432
# office_furniture                   16.504929
# luggage_accessories                15.895195
# Name: mon_growth_pct, dtype: float64

# %%
## End of analysis
